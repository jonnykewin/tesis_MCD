# %%
import os
from pathlib import Path

# 📁 Ruta raíz donde están las ciudades
# 👉 Asegúrate de que esta carpeta contiene las subcarpetas de las escenas (no te metas dentro de una)
ruta_raiz = Path("/home/rohi/Downloads/maestria/10-heat_island")

# 🔍 Buscar recursivamente carpetas que tengan el archivo de temperatura modelo
carpetas_validas = []
for root, dirs, files in os.walk(ruta_raiz):
    files_lower = [f.lower() for f in files]
    # Se aceptan variantes de mayúsculas/minúsculas y .tif / .TIF
    if any(f.startswith("temperature_extratrees") and f.endswith(".tif") for f in files_lower):
        carpetas_validas.append(Path(root))

# 📊 Reporte
print(f"Se encontraron {len(carpetas_validas)} carpetas válidas:\n")
for c in carpetas_validas:
    print("-", c)
# Out:
# Se encontraron 30 carpetas válidas:
#
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20240120_20240129_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20190122_20200830_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20170116_20200905_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20230117_20230131_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20180204_20200902_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20160114_20200907_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20150401_20200909_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_010053_20220222_20220302_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20210212_20220526_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20210212_20220526_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20160114_20200907_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20230117_20230131_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20240120_20240129_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20150401_20200909_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20170116_20200905_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC09_L2SP_009052_20220223_20230427_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20190106_20200830_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20200329_20200822_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20180204_20200902_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20210212_20220526_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20160114_20200907_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20230117_20230131_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20240120_20240129_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20150401_20200909_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20170116_20200905_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC09_L2SP_009052_20220223_20230427_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20190106_20200830_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20200329_20200822_02_T1
# - /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20180204_20200902_02_T1

# %%
import os
from pathlib import Path
import rasterio
import numpy as np

def _resolve_file(carpeta: Path, filename: str) -> Path:
    """Busca un archivo por nombre exacto ignorando mayúsculas/minúsculas (.tif/.TIF)."""
    target = filename.lower()
    for f in os.listdir(carpeta):
        if f.lower() == target:
            return carpeta / f
    raise FileNotFoundError(f"No se encontró {filename} en {carpeta}")

def _read1(path: Path):
    """Lee una banda (1) y retorna (array, profile)."""
    with rasterio.open(path) as src:
        arr = src.read(1)
        profile = src.profile
    return arr, profile

def cargar_rasters_y_mascaras(
    carpeta: Path,
    umbral_densidad_urbano: float = 0.6,
    umbral_densidad_veg: float = 0.6,
    umbral_agua_nube: float = 0.5
):
    """Lee los rásteres base y genera las máscaras de urbano, vegetación y exclusión, validando geometría/CRS."""
    print(f"\n📂 Procesando carpeta: {carpeta.name}")

    # --- Resolver nombres tolerantes a mayúsculas/minúsculas ---
    temp_model_path = _resolve_file(carpeta, "Temperature_ExtraTrees.TIF")
    lst_path        = _resolve_file(carpeta, "LST.TIF")
    sea_path        = _resolve_file(carpeta, "c0_sea_water.TIF")
    fresh_path      = _resolve_file(carpeta, "c1_fresh_water.TIF")
    builds_path     = _resolve_file(carpeta, "c2_builds.TIF")
    clouds_path     = _resolve_file(carpeta, "c3_clouds.TIF")
    bare_path       = _resolve_file(carpeta, "c4_bare_ground.TIF")
    veg_path        = _resolve_file(carpeta, "c5_vegetation.TIF")

    # --- Leer insumos (cerrando handlers) ---
    temp_model, profile = _read1(temp_model_path)
    lst, _       = _read1(lst_path)
    sea, _       = _read1(sea_path)
    fresh, _     = _read1(fresh_path)
    builds, _    = _read1(builds_path)
    clouds, _    = _read1(clouds_path)
    bare, _      = _read1(bare_path)
    vegetation, _= _read1(veg_path)

    # --- Validaciones geométricas básicas ---
    H, W = temp_model.shape
    def _chk(name, arr):
        if arr.shape != (H, W):
            raise ValueError(f"{name} tiene shape {arr.shape} distinto a {temp_model.shape} en {carpeta}")
    _chk("LST", lst); _chk("c0_sea_water", sea); _chk("c1_fresh_water", fresh)
    _chk("c2_builds", builds); _chk("c3_clouds", clouds); _chk("c4_bare_ground", bare); _chk("c5_vegetation", vegetation)

    # --- Construcción de máscaras ---
    urbano = (builds >= umbral_densidad_urbano).astype(np.uint8)
    vegetacion_densa = (vegetation >= umbral_densidad_veg).astype(np.uint8)
    agua = ((sea > umbral_agua_nube) | (fresh > umbral_agua_nube)).astype(np.uint8)
    nubes = (clouds > umbral_agua_nube).astype(np.uint8)
    mascara_exclusion = ((agua == 1) | (nubes == 1)).astype(np.uint8)

    # --- QC rápido ---
    tot_pix = H * W
    u_pix = int(urbano.sum()); v_pix = int(vegetacion_densa.sum()); exc_pix = int(mascara_exclusion.sum())
    print("Máscaras creadas correctamente:")
    print(f"  - Urbano: {u_pix} px ({100*u_pix/tot_pix:.2f}%)  [umbral {umbral_densidad_urbano}]")
    print(f"  - Vegetación densa: {v_pix} px ({100*v_pix/tot_pix:.2f}%)  [umbral {umbral_densidad_veg}]")
    print(f"  - Exclusión (agua/nubes): {exc_pix} px ({100*exc_pix/tot_pix:.2f}%)  [>{umbral_agua_nube}]")

    return {
        "temp_model": temp_model,
        "lst": lst,
        "urbano": urbano,
        "vegetacion": vegetacion_densa,
        "mascara_exclusion": mascara_exclusion,
        "profile": profile
    }

# %%
# Prueba con una carpeta
datos = cargar_rasters_y_mascaras(carpetas_validas[1])
assert set(["temp_model","lst","urbano","vegetacion","mascara_exclusion","profile"]) <= set(datos.keys())
# Out:
# 📂 Procesando carpeta: LC08_L2SP_009053_20240120_20240129_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 94582 px (12.71%)  [umbral 0.6]
#   - Vegetación densa: 225379 px (30.28%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 264252 px (35.51%)  [>0.5]

# %%
import numpy as np
import rasterio
from pathlib import Path

def calcular_deltaT(datos, carpeta, usar_outputs=True, percentil_base=25):
    """
    Calcula la línea base térmica (percentil en vegetación densa sin exclusiones),
    genera DeltaT y lo guarda (opcionalmente) en /outputs.
    Retorna: (deltaT, T_base)
    """
    temp       = datos["temp_model"]           # Temperature_ExtraTrees.TIF
    vegetacion = datos["vegetacion"]           # c5_vegetation >= umbral -> 1
    exc        = datos["mascara_exclusion"]    # agua | nubes
    profile    = datos["profile"]

    # Carpeta de salida
    out_dir = Path(carpeta) if usar_outputs else Path(carpeta)
    out_dir.mkdir(exist_ok=True)

    # Máscara base: vegetación densa, sin exclusiones y valores finitos
    m_base = (vegetacion == 1) & (exc == 0) & np.isfinite(temp)
    if not np.any(m_base):
        raise ValueError("No hay píxeles válidos para calcular la línea base (vegetación densa sin nubes/agua).")

    # Línea base térmica
    T_base = np.nanpercentile(temp[m_base], percentil_base)
    print(f"🌡️  Línea base térmica (P{percentil_base}): {T_base:.2f} °C")

    # DeltaT
    deltaT = temp - T_base

    # Guardar DeltaT
    out_path = out_dir / "DeltaT.TIF"
    profile_f32 = profile.copy()
    profile_f32.update(dtype=rasterio.float32, nodata=np.nan, count=1, compress="lzw")
    with rasterio.open(out_path, "w", **profile_f32) as dst:
        dst.write(deltaT.astype(np.float32), 1)

    print(f"✅ DeltaT guardado en: {out_path}")
    return deltaT, T_base

# %%
deltaT, T_base = calcular_deltaT(datos, carpetas_validas[0])
# Out:
# 🌡️  Línea base térmica (P25): 31.27 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/DeltaT.TIF

# %%
def detectar_icu(datos, deltaT, carpeta, usar_outputs=True):
    import numpy as np
    import rasterio
    import json
    from pathlib import Path

    urbano = datos["urbano"]
    mascara_exclusion = datos["mascara_exclusion"]
    profile = datos["profile"]

    # Carpeta de salida
    output_dir = Path(carpeta)  if usar_outputs else Path(carpeta)
    output_dir.mkdir(exist_ok=True)

    # Área válida: urbano sin exclusiones y con ΔT finito
    mascara_valida = (urbano == 1) & (mascara_exclusion == 0)
    mascara_valid_values = mascara_valida & np.isfinite(deltaT)

    total_urbano = int(np.sum(mascara_valida))
    if total_urbano == 0:
        # Nada de urbano válido: escribir salidas vacías y salir
        icu_intensity = np.zeros_like(deltaT, dtype=np.uint8)
        icu_mask = np.zeros_like(deltaT, dtype=np.uint8)
        profile_u8 = profile.copy()
        profile_u8.update(dtype=rasterio.uint8, nodata=0, count=1, compress="lzw")
        with rasterio.open(output_dir / "ICU_mask.TIF", "w", **profile_u8) as dst:
            dst.write(icu_mask, 1)
        with rasterio.open(output_dir / "ICU_intensity.TIF", "w", **profile_u8) as dst:
            dst.write(icu_intensity, 1)
        print("ℹ️ No hay píxeles urbanos válidos. Archivos ICU vacíos escritos.")
        # metadata mínima
        with open(output_dir / "ICU_metadata.json", "w") as f:
            json.dump({"nota":"sin_urbano_valido","porcentaje_icu":0.0}, f, indent=2)
        return {
            "icu_mask": icu_mask, "icu_intensity": icu_intensity,
            "P75": np.nan, "P90": np.nan, "P97": np.nan,
            "porcentaje_icu": 0.0, "out_dir": str(output_dir)
        }

    # Percentiles sobre urbano válido (ignorando NaN)
    valores_validos = deltaT[mascara_valid_values]
    if valores_validos.size < 10:
        # Con muy pocos píxeles, fija umbral único alto para evitar falsos positivos
        P75 = P90 = P97 = float(np.nanmax(valores_validos)) if valores_validos.size > 0 else np.nan
    else:
        P75, P90, P97 = np.nanpercentile(valores_validos, [75, 90, 97])

    print("📊 Percentiles ΔT (urbano):")
    print(f"   P75 = {P75:.2f} °C | P90 = {P90:.2f} °C | P97 = {P97:.2f} °C")

    # Clasificación por intensidad SOLO en área válida
    icu_intensity = np.zeros_like(deltaT, dtype=np.uint8)
    if np.isfinite(P75) and np.isfinite(P90) and np.isfinite(P97):
        m = mascara_valid_values
        icu_intensity[(deltaT >= P75) & (deltaT < P90) & m] = 1  # Moderada
        icu_intensity[(deltaT >= P90) & (deltaT < P97) & m] = 2  # Alta
        icu_intensity[(deltaT >= P97) & m] = 3                   # Extrema

    # Mapa binario
    icu_mask = (icu_intensity > 0).astype(np.uint8)

    # Guardar
    profile_u8 = profile.copy()
    profile_u8.update(dtype=rasterio.uint8, nodata=0, count=1, compress="lzw")

    out_mask = output_dir / "ICU_mask.TIF"
    out_intensity = output_dir / "ICU_intensity.TIF"

    with rasterio.open(out_mask, "w", **profile_u8) as dst:
        dst.write(icu_mask, 1)
    with rasterio.open(out_intensity, "w", **profile_u8) as dst:
        dst.write(icu_intensity, 1)

    # Métricas
    total_icu = int(np.sum(icu_mask))
    porc_icu = (total_icu / total_urbano) * 100 if total_urbano > 0 else 0.0

    print(f"🏙️ Urbano válido: {total_urbano} px | 🔥 ICU: {total_icu} px ({porc_icu:.2f}%)")
    print(f"✅ Guardado en: {out_mask}\n✅ Guardado en: {out_intensity}")

    # Metadata JSON (trazabilidad)
    with open(output_dir / "ICU_metadata.json", "w") as f:
        json.dump({
            "P75": None if not np.isfinite(P75) else float(P75),
            "P90": None if not np.isfinite(P90) else float(P90),
            "P97": None if not np.isfinite(P97) else float(P97),
            "porcentaje_icu": float(porc_icu),
            "total_urbano_px": total_urbano,
            "total_icu_px": total_icu
        }, f, indent=2)

    return {
        "icu_mask": icu_mask,
        "icu_intensity": icu_intensity,
        "P75": P75, "P90": P90, "P97": P97,
        "porcentaje_icu": porc_icu,
        "out_dir": str(output_dir)
    }

# %%
# Escena de prueba punta-a-punta
carpeta_test = carpetas_validas[0]
d = cargar_rasters_y_mascaras(carpeta_test)
deltaT, T_base = calcular_deltaT(d, carpeta_test, usar_outputs=True, percentil_base=25)
res = detectar_icu(d, deltaT, carpeta_test, usar_outputs=True)
print("T_base:", round(T_base,2), "| %ICU:", round(res["porcentaje_icu"],2))
# Out:
# 📂 Procesando carpeta: LC08_L2SP_009053_20200329_20200822_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 134728 px (18.10%)  [umbral 0.6]
#   - Vegetación densa: 32411 px (4.35%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 255798 px (34.37%)  [>0.5]
# 🌡️  Línea base térmica (P25): 32.09 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = -0.23 °C | P90 = -0.06 °C | P97 = 0.12 °C
# 🏙️ Urbano válido: 134728 px | 🔥 ICU: 33828 px (25.11%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/ICU_intensity.TIF
# T_base: 32.09 | %ICU: 25.11

# %%
import pandas as pd
import re
from pathlib import Path

# Fallback para tqdm si no está instalado
try:
    from tqdm import tqdm
except ModuleNotFoundError:
    def tqdm(x, **k): return x

def extraer_ciudad_y_fecha(path_str: str):
    p = Path(path_str)
    ciudad = p.parent.name                  # p.ej. cartagena / barranquilla / santa_marta
    m = re.search(r'_(\d{8})_', p.name)     # captura YYYYMMDD en nombre de escena
    fecha = m.group(1) if m else None
    return ciudad, fecha

def procesar_carpeta(carpeta: Path):
    """Ejecuta todos los pasos para una carpeta y devuelve un registro para el resumen."""
    try:
        # Paso 2
        datos = cargar_rasters_y_mascaras(carpeta)

        # Paso 3
        deltaT, T_base = calcular_deltaT(datos, carpeta, usar_outputs=True, percentil_base=25)

        # Paso 4
        resultados = detectar_icu(datos, deltaT, carpeta, usar_outputs=True)

        ciudad, fecha = extraer_ciudad_y_fecha(str(carpeta))
        return {
            "ciudad": ciudad,
            "fecha": fecha,
            "carpeta": str(carpeta),
            "T_base_P25": round(T_base, 3),
            "P75": round(resultados["P75"], 3) if resultados["P75"]==resultados["P75"] else None,
            "P90": round(resultados["P90"], 3) if resultados["P90"]==resultados["P90"] else None,
            "P97": round(resultados["P97"], 3) if resultados["P97"]==resultados["P97"] else None,
            "porc_icu": round(resultados["porcentaje_icu"], 3),
            "output_dir": resultados["out_dir"]
        }
    except Exception as e:
        print(f"⚠️  Error en {carpeta.name}: {e}")
        return None

# 🔁 Procesar todas las carpetas válidas
registros = []
for carpeta in tqdm(carpetas_validas, desc="Procesando escenas"):
    res = procesar_carpeta(carpeta)
    if res:
        registros.append(res)

# 📊 Crear resumen global ordenado
df = pd.DataFrame(registros)
cols = ["ciudad","fecha","carpeta","T_base_P25","P75","P90","P97","porc_icu","output_dir"]
df = df[cols] if not df.empty else df

csv_path = ruta_raiz / "resumen_ICU.csv"
df.to_csv(csv_path, index=False)

print(f"\n✅ Procesamiento completado.")
print(f"📄 Resumen global guardado en: {csv_path}")
display(df)
# Out:
# 📂 Procesando carpeta: LC08_L2SP_009053_20200329_20200822_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 134728 px (18.10%)  [umbral 0.6]
#   - Vegetación densa: 32411 px (4.35%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 255798 px (34.37%)  [>0.5]
# 🌡️  Línea base térmica (P25): 32.09 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = -0.23 °C | P90 = -0.06 °C | P97 = 0.12 °C
# 🏙️ Urbano válido: 134728 px | 🔥 ICU: 33828 px (25.11%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20200329_20200822_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20240120_20240129_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 94582 px (12.71%)  [umbral 0.6]
#   - Vegetación densa: 225379 px (30.28%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 264252 px (35.51%)  [>0.5]
# 🌡️  Línea base térmica (P25): 31.27 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20240120_20240129_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.07 °C | P90 = 0.18 °C | P97 = 0.33 °C
# 🏙️ Urbano válido: 94582 px | 🔥 ICU: 23646 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20240120_20240129_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20240120_20240129_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20190122_20200830_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 101404 px (13.62%)  [umbral 0.6]
#   - Vegetación densa: 212755 px (28.59%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 208012 px (27.95%)  [>0.5]
# 🌡️  Línea base térmica (P25): 30.41 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20190122_20200830_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.40 °C | P90 = 0.43 °C | P97 = 0.47 °C
# 🏙️ Urbano válido: 101404 px | 🔥 ICU: 25351 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20190122_20200830_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20190122_20200830_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20170116_20200905_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 92559 px (12.44%)  [umbral 0.6]
#   - Vegetación densa: 297244 px (39.94%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 265702 px (35.70%)  [>0.5]
# 🌡️  Línea base térmica (P25): 29.26 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20170116_20200905_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.53 °C | P90 = 0.62 °C | P97 = 0.68 °C
# 🏙️ Urbano válido: 92559 px | 🔥 ICU: 23140 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20170116_20200905_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20170116_20200905_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20230117_20230131_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 86506 px (11.62%)  [umbral 0.6]
#   - Vegetación densa: 317742 px (42.69%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 247089 px (33.20%)  [>0.5]
# 🌡️  Línea base térmica (P25): 29.10 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20230117_20230131_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.36 °C | P90 = 0.55 °C | P97 = 0.71 °C
# 🏙️ Urbano válido: 86506 px | 🔥 ICU: 21627 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20230117_20230131_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20230117_20230131_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20180204_20200902_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 94788 px (12.74%)  [umbral 0.6]
#   - Vegetación densa: 278540 px (37.43%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 243484 px (32.71%)  [>0.5]
# 🌡️  Línea base térmica (P25): 30.50 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20180204_20200902_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = -0.25 °C | P90 = 0.08 °C | P97 = 0.57 °C
# 🏙️ Urbano válido: 94788 px | 🔥 ICU: 23697 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20180204_20200902_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20180204_20200902_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20160114_20200907_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 105184 px (14.13%)  [umbral 0.6]
#   - Vegetación densa: 129417 px (17.39%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 257987 px (34.66%)  [>0.5]
# 🌡️  Línea base térmica (P25): 29.42 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20160114_20200907_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.95 °C | P90 = 1.11 °C | P97 = 1.20 °C
# 🏙️ Urbano válido: 105184 px | 🔥 ICU: 26296 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20160114_20200907_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20160114_20200907_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20150401_20200909_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 114960 px (15.45%)  [umbral 0.6]
#   - Vegetación densa: 58519 px (7.86%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 259727 px (34.90%)  [>0.5]
# 🌡️  Línea base térmica (P25): 30.41 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20150401_20200909_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = -0.04 °C | P90 = 0.18 °C | P97 = 0.46 °C
# 🏙️ Urbano válido: 114960 px | 🔥 ICU: 28740 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20150401_20200909_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20150401_20200909_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_010053_20220222_20220302_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 96730 px (13.03%)  [umbral 0.6]
#   - Vegetación densa: 57068 px (7.69%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 266120 px (35.84%)  [>0.5]
# 🌡️  Línea base térmica (P25): 30.88 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_010053_20220222_20220302_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.00 °C | P90 = 0.15 °C | P97 = 0.45 °C
# 🏙️ Urbano válido: 96730 px | 🔥 ICU: 24183 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_010053_20220222_20220302_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_010053_20220222_20220302_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009053_20210212_20220526_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 99112 px (13.32%)  [umbral 0.6]
#   - Vegetación densa: 171132 px (22.99%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 259229 px (34.83%)  [>0.5]
# 🌡️  Línea base térmica (P25): 31.00 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20210212_20220526_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = -0.12 °C | P90 = 0.26 °C | P97 = 0.71 °C
# 🏙️ Urbano válido: 99112 px | 🔥 ICU: 24778 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20210212_20220526_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/cartagena/LC08_L2SP_009053_20210212_20220526_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20210212_20220526_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 122976 px (33.41%)  [umbral 0.6]
#   - Vegetación densa: 58263 px (15.83%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 99491 px (27.03%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.52 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20210212_20220526_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 1.26 °C | P90 = 1.36 °C | P97 = 1.44 °C
# 🏙️ Urbano válido: 122976 px | 🔥 ICU: 30744 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20210212_20220526_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20210212_20220526_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20160114_20200907_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 119561 px (32.48%)  [umbral 0.6]
#   - Vegetación densa: 55341 px (15.04%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 101353 px (27.54%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.00 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20160114_20200907_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.56 °C | P90 = 0.70 °C | P97 = 0.87 °C
# 🏙️ Urbano válido: 119561 px | 🔥 ICU: 29891 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20160114_20200907_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20160114_20200907_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20230117_20230131_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 111040 px (30.17%)  [umbral 0.6]
#   - Vegetación densa: 87211 px (23.69%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 101161 px (27.48%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.33 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20230117_20230131_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.89 °C | P90 = 1.00 °C | P97 = 1.12 °C
# 🏙️ Urbano válido: 111040 px | 🔥 ICU: 27760 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20230117_20230131_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20230117_20230131_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20240120_20240129_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 117273 px (31.86%)  [umbral 0.6]
#   - Vegetación densa: 90195 px (24.50%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 100383 px (27.27%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.49 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20240120_20240129_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 1.18 °C | P90 = 1.28 °C | P97 = 1.38 °C
# 🏙️ Urbano válido: 117273 px | 🔥 ICU: 29319 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20240120_20240129_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20240120_20240129_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20150401_20200909_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 144610 px (39.29%)  [umbral 0.6]
#   - Vegetación densa: 37421 px (10.17%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 98384 px (26.73%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.34 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20150401_20200909_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 1.27 °C | P90 = 1.30 °C | P97 = 1.36 °C
# 🏙️ Urbano válido: 144610 px | 🔥 ICU: 36154 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20150401_20200909_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20150401_20200909_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20170116_20200905_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 112020 px (30.43%)  [umbral 0.6]
#   - Vegetación densa: 110111 px (29.91%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 103013 px (27.99%)  [>0.5]
# 🌡️  Línea base térmica (P25): 26.74 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20170116_20200905_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.54 °C | P90 = 0.76 °C | P97 = 0.96 °C
# 🏙️ Urbano válido: 112020 px | 🔥 ICU: 28005 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20170116_20200905_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20170116_20200905_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC09_L2SP_009052_20220223_20230427_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 134479 px (36.54%)  [umbral 0.6]
#   - Vegetación densa: 54214 px (14.73%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 99309 px (26.98%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.48 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC09_L2SP_009052_20220223_20230427_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.56 °C | P90 = 0.69 °C | P97 = 0.85 °C
# 🏙️ Urbano válido: 134479 px | 🔥 ICU: 33620 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC09_L2SP_009052_20220223_20230427_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC09_L2SP_009052_20220223_20230427_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20190106_20200830_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 114504 px (31.11%)  [umbral 0.6]
#   - Vegetación densa: 64567 px (17.54%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 129989 px (35.32%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.23 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20190106_20200830_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.42 °C | P90 = 0.57 °C | P97 = 0.81 °C
# 🏙️ Urbano válido: 114504 px | 🔥 ICU: 28626 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20190106_20200830_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20190106_20200830_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20200329_20200822_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 152973 px (41.56%)  [umbral 0.6]
#   - Vegetación densa: 38220 px (10.38%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 98291 px (26.70%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.66 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20200329_20200822_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 1.15 °C | P90 = 1.23 °C | P97 = 1.32 °C
# 🏙️ Urbano válido: 152973 px | 🔥 ICU: 38248 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20200329_20200822_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20200329_20200822_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20180204_20200902_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 115081 px (31.27%)  [umbral 0.6]
#   - Vegetación densa: 68848 px (18.70%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 101738 px (27.64%)  [>0.5]
# 🌡️  Línea base térmica (P25): 27.30 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20180204_20200902_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 0.68 °C | P90 = 0.78 °C | P97 = 0.91 °C
# 🏙️ Urbano válido: 115081 px | 🔥 ICU: 28771 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20180204_20200902_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/barranquilla/LC08_L2SP_009052_20180204_20200902_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20210212_20220526_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 42016 px (12.50%)  [umbral 0.6]
#   - Vegetación densa: 136191 px (40.53%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 47568 px (14.16%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.37 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20210212_20220526_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.66 °C | P90 = 5.94 °C | P97 = 6.16 °C
# 🏙️ Urbano válido: 42016 px | 🔥 ICU: 10504 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20210212_20220526_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20210212_20220526_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20160114_20200907_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 43948 px (13.08%)  [umbral 0.6]
#   - Vegetación densa: 134091 px (39.91%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 48509 px (14.44%)  [>0.5]
# 🌡️  Línea base térmica (P25): 23.84 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20160114_20200907_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.64 °C | P90 = 5.88 °C | P97 = 6.03 °C
# 🏙️ Urbano válido: 43948 px | 🔥 ICU: 10987 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20160114_20200907_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20160114_20200907_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20230117_20230131_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 35042 px (10.43%)  [umbral 0.6]
#   - Vegetación densa: 169309 px (50.39%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 46589 px (13.87%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.12 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20230117_20230131_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.93 °C | P90 = 6.23 °C | P97 = 6.44 °C
# 🏙️ Urbano válido: 35042 px | 🔥 ICU: 8761 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20230117_20230131_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20230117_20230131_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20240120_20240129_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 41268 px (12.28%)  [umbral 0.6]
#   - Vegetación densa: 151922 px (45.22%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 46116 px (13.73%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.41 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20240120_20240129_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.87 °C | P90 = 6.14 °C | P97 = 6.32 °C
# 🏙️ Urbano válido: 41268 px | 🔥 ICU: 10317 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20240120_20240129_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20240120_20240129_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20150401_20200909_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 57736 px (17.18%)  [umbral 0.6]
#   - Vegetación densa: 47644 px (14.18%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 51818 px (15.42%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.43 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20150401_20200909_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.23 °C | P90 = 5.44 °C | P97 = 5.56 °C
# 🏙️ Urbano válido: 57736 px | 🔥 ICU: 14434 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20150401_20200909_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20150401_20200909_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20170116_20200905_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 40976 px (12.20%)  [umbral 0.6]
#   - Vegetación densa: 165239 px (49.18%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 48264 px (14.36%)  [>0.5]
# 🌡️  Línea base térmica (P25): 23.51 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20170116_20200905_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.93 °C | P90 = 6.17 °C | P97 = 6.34 °C
# 🏙️ Urbano válido: 40976 px | 🔥 ICU: 10244 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20170116_20200905_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20170116_20200905_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC09_L2SP_009052_20220223_20230427_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 50873 px (15.14%)  [umbral 0.6]
#   - Vegetación densa: 74555 px (22.19%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 62085 px (18.48%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.14 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC09_L2SP_009052_20220223_20230427_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 6.10 °C | P90 = 6.37 °C | P97 = 6.56 °C
# 🏙️ Urbano válido: 50873 px | 🔥 ICU: 12719 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC09_L2SP_009052_20220223_20230427_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC09_L2SP_009052_20220223_20230427_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20190106_20200830_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 45900 px (13.66%)  [umbral 0.6]
#   - Vegetación densa: 175399 px (52.20%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 48730 px (14.50%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.29 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20190106_20200830_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.73 °C | P90 = 6.00 °C | P97 = 6.18 °C
# 🏙️ Urbano válido: 45900 px | 🔥 ICU: 11475 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20190106_20200830_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20190106_20200830_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20200329_20200822_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 65616 px (19.53%)  [umbral 0.6]
#   - Vegetación densa: 57040 px (16.98%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 45423 px (13.52%)  [>0.5]
# 🌡️  Línea base térmica (P25): 25.38 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20200329_20200822_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.15 °C | P90 = 5.41 °C | P97 = 5.58 °C
# 🏙️ Urbano válido: 65616 px | 🔥 ICU: 16404 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20200329_20200822_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20200329_20200822_02_T1/ICU_intensity.TIF
#
# 📂 Procesando carpeta: LC08_L2SP_009052_20180204_20200902_02_T1
# Máscaras creadas correctamente:
#   - Urbano: 39463 px (11.75%)  [umbral 0.6]
#   - Vegetación densa: 139647 px (41.56%)  [umbral 0.6]
#   - Exclusión (agua/nubes): 49642 px (14.77%)  [>0.5]
# 🌡️  Línea base térmica (P25): 24.19 °C
# ✅ DeltaT guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20180204_20200902_02_T1/DeltaT.TIF
# 📊 Percentiles ΔT (urbano):
#    P75 = 5.66 °C | P90 = 5.91 °C | P97 = 6.08 °C
# 🏙️ Urbano válido: 39463 px | 🔥 ICU: 9866 px (25.00%)
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20180204_20200902_02_T1/ICU_mask.TIF
# ✅ Guardado en: /home/rohi/Downloads/maestria/10-heat_island/santa_marta/LC08_L2SP_009052_20180204_20200902_02_T1/ICU_intensity.TIF
#
# ✅ Procesamiento completado.
# 📄 Resumen global guardado en: /home/rohi/Downloads/maestria/10-heat_island/resumen_ICU.csv
#           ciudad     fecha                                            carpeta  \
# 0      cartagena  20200329  /home/rohi/Downloads/maestria/10-heat_island/c...
# 1      cartagena  20240120  /home/rohi/Downloads/maestria/10-heat_island/c...
# 2      cartagena  20190122  /home/rohi/Downloads/maestria/10-heat_island/c...
# 3      cartagena  20170116  /home/rohi/Downloads/maestria/10-heat_island/c...
# 4      cartagena  20230117  /home/rohi/Downloads/maestria/10-heat_island/c...
# 5      cartagena  20180204  /home/rohi/Downloads/maestria/10-heat_island/c...
# 6      cartagena  20160114  /home/rohi/Downloads/maestria/10-heat_island/c...
# 7      cartagena  20150401  /home/rohi/Downloads/maestria/10-heat_island/c...
# 8      cartagena  20220222  /home/rohi/Downloads/maestria/10-heat_island/c...
# 9      cartagena  20210212  /home/rohi/Downloads/maestria/10-heat_island/c...
# 10  barranquilla  20210212  /home/rohi/Downloads/maestria/10-heat_island/b...
# 11  barranquilla  20160114  /home/rohi/Downloads/maestria/10-heat_island/b...
# 12  barranquilla  20230117  /home/rohi/Downloads/maestria/10-heat_island/b...
# 13  barranquilla  20240120  /home/rohi/Downloads/maestria/10-heat_island/b...
# 14  barranquilla  20150401  /home/rohi/Downloads/maestria/10-heat_island/b...
# 15  barranquilla  20170116  /home/rohi/Downloads/maestria/10-heat_island/b...
# 16  barranquilla  20220223  /home/rohi/Downloads/maestria/10-heat_island/b...
# 17  barranquilla  20190106  /home/rohi/Downloads/maestria/10-heat_island/b...
# 18  barranquilla  20200329  /home/rohi/Downloads/maestria/10-heat_island/b...
# 19  barranquilla  20180204  /home/rohi/Downloads/maestria/10-heat_island/b...
# 20   santa_marta  20210212  /home/rohi/Downloads/maestria/10-heat_island/s...
# 21   santa_marta  20160114  /home/rohi/Downloads/maestria/10-heat_island/s...
# 22   santa_marta  20230117  /home/rohi/Downloads/maestria/10-heat_island/s...
# 23   santa_marta  20240120  /home/rohi/Downloads/maestria/10-heat_island/s...
# 24   santa_marta  20150401  /home/rohi/Downloads/maestria/10-heat_island/s...
# 25   santa_marta  20170116  /home/rohi/Downloads/maestria/10-heat_island/s...
# 26   santa_marta  20220223  /home/rohi/Downloads/maestria/10-heat_island/s...
# 27   santa_marta  20190106  /home/rohi/Downloads/maestria/10-heat_island/s...
# 28   santa_marta  20200329  /home/rohi/Downloads/maestria/10-heat_island/s...
# 29   santa_marta  20180204  /home/rohi/Downloads/maestria/10-heat_island/s...
#
#     T_base_P25    P75    P90    P97  porc_icu  \
# 0    32.088001 -0.230 -0.058  0.121    25.108
# 1    31.266001  0.073  0.177  0.325    25.001
# 2    30.408001  0.400  0.427  0.468    25.000
# 3    29.257000  0.535  0.621  0.682    25.000
# 4    29.104000  0.355  0.545  0.707    25.001
# 5    30.504000 -0.253  0.084  0.574    25.000
# 6    29.424999  0.953  1.113  1.202    25.000
# 7    30.415001 -0.040  0.180  0.456    25.000
# 8    30.882000  0.002  0.147  0.454    25.001
# 9    31.002001 -0.117  0.257  0.714    25.000
# 10   27.518999  1.260  1.361  1.436    25.000
# 11   26.999001  0.558  0.699  0.868    25.001
# 12   27.333000  0.890  1.002  1.121    25.000
# 13   27.493000  1.182  1.276  1.380    25.001
# 14   27.339001  1.273  1.300  1.355    25.001
# 15   26.743000  0.537  0.763  0.961    25.000
# 16   27.483000  0.565  0.692  0.851    25.000
# 17   27.228001  0.423  0.575  0.809    25.000
# 18   27.656000  1.151  1.227  1.320    25.003
# 19   27.297001  0.681  0.782  0.914    25.001
# 20   24.375000  5.662  5.940  6.164    25.000
# 21   23.839001  5.638  5.879  6.033    25.000
# 22   24.120001  5.934  6.231  6.445    25.001
# 23   24.410999  5.870  6.135  6.321    25.000
# 24   24.434999  5.227  5.440  5.565    25.000
# 25   23.507000  5.928  6.166  6.340    25.000
# 26   24.143999  6.100  6.373  6.557    25.001
# 27   24.289000  5.732  5.998  6.183    25.000
# 28   25.385000  5.147  5.414  5.585    25.000
# 29   24.188000  5.658  5.906  6.080    25.001
#
#                                            output_dir
# 0   /home/rohi/Downloads/maestria/10-heat_island/c...
# 1   /home/rohi/Downloads/maestria/10-heat_island/c...
# 2   /home/rohi/Downloads/maestria/10-heat_island/c...
# 3   /home/rohi/Downloads/maestria/10-heat_island/c...
# 4   /home/rohi/Downloads/maestria/10-heat_island/c...
# 5   /home/rohi/Downloads/maestria/10-heat_island/c...
# 6   /home/rohi/Downloads/maestria/10-heat_island/c...
# 7   /home/rohi/Downloads/maestria/10-heat_island/c...
# 8   /home/rohi/Downloads/maestria/10-heat_island/c...
# 9   /home/rohi/Downloads/maestria/10-heat_island/c...
# 10  /home/rohi/Downloads/maestria/10-heat_island/b...
# 11  /home/rohi/Downloads/maestria/10-heat_island/b...
# 12  /home/rohi/Downloads/maestria/10-heat_island/b...
# 13  /home/rohi/Downloads/maestria/10-heat_island/b...
# 14  /home/rohi/Downloads/maestria/10-heat_island/b...
# 15  /home/rohi/Downloads/maestria/10-heat_island/b...
# 16  /home/rohi/Downloads/maestria/10-heat_island/b...
# 17  /home/rohi/Downloads/maestria/10-heat_island/b...
# 18  /home/rohi/Downloads/maestria/10-heat_island/b...
# 19  /home/rohi/Downloads/maestria/10-heat_island/b...
# 20  /home/rohi/Downloads/maestria/10-heat_island/s...
# 21  /home/rohi/Downloads/maestria/10-heat_island/s...
# 22  /home/rohi/Downloads/maestria/10-heat_island/s...
# 23  /home/rohi/Downloads/maestria/10-heat_island/s...
# 24  /home/rohi/Downloads/maestria/10-heat_island/s...
# 25  /home/rohi/Downloads/maestria/10-heat_island/s...
# 26  /home/rohi/Downloads/maestria/10-heat_island/s...
# 27  /home/rohi/Downloads/maestria/10-heat_island/s...
# 28  /home/rohi/Downloads/maestria/10-heat_island/s...
# 29  /home/rohi/Downloads/maestria/10-heat_island/s...

# %%
import re

def extraer_ciudad_y_fecha(path_str: str):
    # ciudad = carpeta madre inmediata (ej. .../cartagena/LC08_.../ )
    p = Path(path_str)
    ciudad = p.parent.name  # cartagena / barranquilla / santa_marta / etc.

    # fecha = primera secuencia de 8 dígitos en el nombre de la escena
    m = re.search(r'_(\d{8})_', p.name)
    fecha = m.group(1) if m else None  # 'YYYYMMDD'
    return ciudad, fecha

# aplicar al dataframe ya creado (df)
df[["ciudad","fecha"]] = df["carpeta"].apply(lambda s: pd.Series(extraer_ciudad_y_fecha(s)))

# reordenar columnas
cols = ["ciudad","fecha","carpeta","T_base_P25","P75","P90","P97","porc_icu","output_dir"]
df = df[cols]

# guardar de nuevo
csv_path = ruta_raiz / "resumen_ICU.csv"
df.to_csv(csv_path, index=False)
display(df)
# Out:
#           ciudad     fecha                                            carpeta  \
# 0      cartagena  20200329  /home/rohi/Downloads/maestria/10-heat_island/c...
# 1      cartagena  20240120  /home/rohi/Downloads/maestria/10-heat_island/c...
# 2      cartagena  20190122  /home/rohi/Downloads/maestria/10-heat_island/c...
# 3      cartagena  20170116  /home/rohi/Downloads/maestria/10-heat_island/c...
# 4      cartagena  20230117  /home/rohi/Downloads/maestria/10-heat_island/c...
# 5      cartagena  20180204  /home/rohi/Downloads/maestria/10-heat_island/c...
# 6      cartagena  20160114  /home/rohi/Downloads/maestria/10-heat_island/c...
# 7      cartagena  20150401  /home/rohi/Downloads/maestria/10-heat_island/c...
# 8      cartagena  20220222  /home/rohi/Downloads/maestria/10-heat_island/c...
# 9      cartagena  20210212  /home/rohi/Downloads/maestria/10-heat_island/c...
# 10  barranquilla  20210212  /home/rohi/Downloads/maestria/10-heat_island/b...
# 11  barranquilla  20160114  /home/rohi/Downloads/maestria/10-heat_island/b...
# 12  barranquilla  20230117  /home/rohi/Downloads/maestria/10-heat_island/b...
# 13  barranquilla  20240120  /home/rohi/Downloads/maestria/10-heat_island/b...
# 14  barranquilla  20150401  /home/rohi/Downloads/maestria/10-heat_island/b...
# 15  barranquilla  20170116  /home/rohi/Downloads/maestria/10-heat_island/b...
# 16  barranquilla  20220223  /home/rohi/Downloads/maestria/10-heat_island/b...
# 17  barranquilla  20190106  /home/rohi/Downloads/maestria/10-heat_island/b...
# 18  barranquilla  20200329  /home/rohi/Downloads/maestria/10-heat_island/b...
# 19  barranquilla  20180204  /home/rohi/Downloads/maestria/10-heat_island/b...
# 20   santa_marta  20210212  /home/rohi/Downloads/maestria/10-heat_island/s...
# 21   santa_marta  20160114  /home/rohi/Downloads/maestria/10-heat_island/s...
# 22   santa_marta  20230117  /home/rohi/Downloads/maestria/10-heat_island/s...
# 23   santa_marta  20240120  /home/rohi/Downloads/maestria/10-heat_island/s...
# 24   santa_marta  20150401  /home/rohi/Downloads/maestria/10-heat_island/s...
# 25   santa_marta  20170116  /home/rohi/Downloads/maestria/10-heat_island/s...
# 26   santa_marta  20220223  /home/rohi/Downloads/maestria/10-heat_island/s...
# 27   santa_marta  20190106  /home/rohi/Downloads/maestria/10-heat_island/s...
# 28   santa_marta  20200329  /home/rohi/Downloads/maestria/10-heat_island/s...
# 29   santa_marta  20180204  /home/rohi/Downloads/maestria/10-heat_island/s...
#
#     T_base_P25    P75    P90    P97  porc_icu  \
# 0    32.088001 -0.230 -0.058  0.121    25.108
# 1    31.266001  0.073  0.177  0.325    25.001
# 2    30.408001  0.400  0.427  0.468    25.000
# 3    29.257000  0.535  0.621  0.682    25.000
# 4    29.104000  0.355  0.545  0.707    25.001
# 5    30.504000 -0.253  0.084  0.574    25.000
# 6    29.424999  0.953  1.113  1.202    25.000
# 7    30.415001 -0.040  0.180  0.456    25.000
# 8    30.882000  0.002  0.147  0.454    25.001
# 9    31.002001 -0.117  0.257  0.714    25.000
# 10   27.518999  1.260  1.361  1.436    25.000
# 11   26.999001  0.558  0.699  0.868    25.001
# 12   27.333000  0.890  1.002  1.121    25.000
# 13   27.493000  1.182  1.276  1.380    25.001
# 14   27.339001  1.273  1.300  1.355    25.001
# 15   26.743000  0.537  0.763  0.961    25.000
# 16   27.483000  0.565  0.692  0.851    25.000
# 17   27.228001  0.423  0.575  0.809    25.000
# 18   27.656000  1.151  1.227  1.320    25.003
# 19   27.297001  0.681  0.782  0.914    25.001
# 20   24.375000  5.662  5.940  6.164    25.000
# 21   23.839001  5.638  5.879  6.033    25.000
# 22   24.120001  5.934  6.231  6.445    25.001
# 23   24.410999  5.870  6.135  6.321    25.000
# 24   24.434999  5.227  5.440  5.565    25.000
# 25   23.507000  5.928  6.166  6.340    25.000
# 26   24.143999  6.100  6.373  6.557    25.001
# 27   24.289000  5.732  5.998  6.183    25.000
# 28   25.385000  5.147  5.414  5.585    25.000
# 29   24.188000  5.658  5.906  6.080    25.001
#
#                                            output_dir
# 0   /home/rohi/Downloads/maestria/10-heat_island/c...
# 1   /home/rohi/Downloads/maestria/10-heat_island/c...
# 2   /home/rohi/Downloads/maestria/10-heat_island/c...
# 3   /home/rohi/Downloads/maestria/10-heat_island/c...
# 4   /home/rohi/Downloads/maestria/10-heat_island/c...
# 5   /home/rohi/Downloads/maestria/10-heat_island/c...
# 6   /home/rohi/Downloads/maestria/10-heat_island/c...
# 7   /home/rohi/Downloads/maestria/10-heat_island/c...
# 8   /home/rohi/Downloads/maestria/10-heat_island/c...
# 9   /home/rohi/Downloads/maestria/10-heat_island/c...
# 10  /home/rohi/Downloads/maestria/10-heat_island/b...
# 11  /home/rohi/Downloads/maestria/10-heat_island/b...
# 12  /home/rohi/Downloads/maestria/10-heat_island/b...
# 13  /home/rohi/Downloads/maestria/10-heat_island/b...
# 14  /home/rohi/Downloads/maestria/10-heat_island/b...
# 15  /home/rohi/Downloads/maestria/10-heat_island/b...
# 16  /home/rohi/Downloads/maestria/10-heat_island/b...
# 17  /home/rohi/Downloads/maestria/10-heat_island/b...
# 18  /home/rohi/Downloads/maestria/10-heat_island/b...
# 19  /home/rohi/Downloads/maestria/10-heat_island/b...
# 20  /home/rohi/Downloads/maestria/10-heat_island/s...
# 21  /home/rohi/Downloads/maestria/10-heat_island/s...
# 22  /home/rohi/Downloads/maestria/10-heat_island/s...
# 23  /home/rohi/Downloads/maestria/10-heat_island/s...
# 24  /home/rohi/Downloads/maestria/10-heat_island/s...
# 25  /home/rohi/Downloads/maestria/10-heat_island/s...
# 26  /home/rohi/Downloads/maestria/10-heat_island/s...
# 27  /home/rohi/Downloads/maestria/10-heat_island/s...
# 28  /home/rohi/Downloads/maestria/10-heat_island/s...
# 29  /home/rohi/Downloads/maestria/10-heat_island/s...
